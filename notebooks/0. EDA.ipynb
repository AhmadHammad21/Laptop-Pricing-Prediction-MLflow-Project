# %%
import pandas as pd
data = pd.read_csv("./data/laptop_prices.csv")

# %%
data.shape
# Out:
# (1275, 23)

# %%
data.hist();

# %%
data.head(2)
# Out:
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq CPU_model  \
# 0  Standard     2560  ...            Yes       Intel      2.3   Core i5
# 1  Standard     1440  ...             No       Intel      1.8   Core i5
#
#   PrimaryStorage  SecondaryStorage PrimaryStorageType  SecondaryStorageType  \
# 0            128                 0                SSD                    No
# 1            128                 0      Flash Storage                    No
#
#    GPU_company               GPU_model
# 0        Intel  Iris Plus Graphics 640
# 1        Intel        HD Graphics 6000
#
# [2 rows x 23 columns]

# %%
chunk_df = data[['Ram', 'Weight', 'Inches', 'ScreenW', 'ScreenH', 'PrimaryStorage', 'Price_euros']]
chunk_df
# Out:
#       Ram  Weight  Inches  ScreenW  ScreenH  PrimaryStorage  Price_euros
# 0       8    1.37    13.3     2560     1600             128      1339.69
# 1       8    1.34    13.3     1440      900             128       898.94
# 2       8    1.86    15.6     1920     1080             256       575.00
# 3      16    1.83    15.4     2880     1800             512      2537.45
# 4       8    1.37    13.3     2560     1600             256      1803.60
# ...   ...     ...     ...      ...      ...             ...          ...
# 1270    4    1.80    14.0     1920     1080             128       638.00
# 1271   16    1.30    13.3     3200     1800             512      1499.00
# 1272    2    1.50    14.0     1366      768              64       229.00
# 1273    6    2.19    15.6     1366      768            1024       764.00
# 1274    4    2.20    15.6     1366      768             500       369.00
#
# [1275 rows x 7 columns]

# %%
chunk_df.to_csv("./data/final/experiment_1.csv", index=False)
